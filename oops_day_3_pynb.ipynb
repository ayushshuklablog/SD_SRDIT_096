# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushshuklablog/SD_SRDIT_096/blob/main/oops_day_3_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l= [1,3,4,5,6,7]

# %%
from functools import reduce
reduce(lambda x,y : x+y ,l)
# Out:
# 26

# %%
reduce(lambda x,y : x+y ,l)
# Out:
# 26

# %%
reduce(lambda x,y : x*y ,l)
# Out:
# 2520

# %%
reduce(lambda x,y : x if x>y else y ,l)
# Out:
# 7

# %%
reduce(lambda x,y :x%y,l)
# Out:
# 1
