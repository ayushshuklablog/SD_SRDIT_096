# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushshuklablog/SD_SRDIT_096/blob/main/oops2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Project On Expense Tracker

stored_password = "Ayush123"

# Expense data
expenses = [
    {"Category": "Food", "Amount": 500},
    {"Category": "Travel", "Amount": 1200},
    {"Category": "Shopping", "Amount": 800},
    {"Category": "Electricity Bill", "Amount": 1500}
]

# User enters password
password = input("Enter Password: ")

# Check password
if password == stored_password:
    print("\nLogin Successful!")
    print("\nYour Expenses:")

    total = 0
    for expense in expenses:
        print(f"{expense['Category']} : ₹{expense['Amount']}")
        total += expense['Amount']

    print("-----------------------")
    print("Total Expense = ₹", total)

else:
    print("Wrong Password!")
# Out:
# Enter Password: Ayush123
#
# Login Successful!
#
# Your Expenses:
# Food : ₹500
# Travel : ₹1200
# Shopping : ₹800
# Electricity Bill : ₹1500
# -----------------------
# Total Expense = ₹ 4000

# %%
# Project On Expense Tracker

stored_name = "Hari"
stored_password = "hari123"
stored_id = "12345"

# Expense data
expenses = [
    {"Category": "Food", "Amount": 500},
    {"Category": "Travel", "Amount": 1200},
    {"Category": "Shopping", "Amount": 800},
    {"Category": "Electricity Bill", "Amount": 1500}
]

# User enters details
name = input("Enter Name: ")
password = input("Enter Password: ")
id = input("Enter ID: ")

# Check ID
if id == stored_id:
    # Check name and password
    if name == stored_name and password == stored_password and id ==stored_id :
        print("\nLogin Successful!")
        print("Welcome,", name)
        print("\nYour Expenses:")

        total = 0
        for expense in expenses:
            print(f"{expense['Category']} : ₹{expense['Amount']}")
            total += expense["Amount"]

        print("-----------------------")
        print("Total Expense = ₹", total)

    else:
        print("Wrong Name or Password!")
else:
    print("Wrong ID!")
# Note: There is no 'else' block for the outer 'if id == stored_id:', which means if the ID is incorrect, nothing will be printed. You might want to add an 'else' here for better user feedback.
